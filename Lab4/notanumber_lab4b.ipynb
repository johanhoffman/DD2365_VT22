# %% [markdown]
# <a href="https://colab.research.google.com/github/johanhoffman/DD2365_VT22/blob/notanumber-lab4/Lab4/notanumber_lab4b.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Elasticity equations**
# **Johan Hoffman**

# %% [markdown]
# # **Abstract**

# %% [markdown]
# This short report show an example on how to use FEniCS to solve the Elasticity equations, which is used in the course DD2365 Advanced Computation in Fluid Mechanics, at the KTH Royal Institute of Technology.
#
# The displacement response of a solid was investigated when an equal displacement of a few features in the solid was prescribed. The changes in behavior depending on Young's modulus and Poisson's ratio was studied. It was seen that the material between the features moved together with the features; that Young's modulus does not affect the solution, and that the solution changes a lot when Poisson's ratio is increased.
#
# [DD2365 course website.](https://kth.instructure.com/courses/17071)

# %% [markdown]
# # **About the code**

# %%
"""This program is an example file for the course"""
"""DD2365 Advanced Computation in Fluid Mechanics, """
"""KTH Royal Institute of Technology, Stockholm, Sweden."""

# Copyright (C) 2021 Johan Hoffman (jhoffman@kth.se)

# This file is part of the course DD2365 Advanced Computation in Fluid Mechanics
# KTH Royal Institute of Technology, Stockholm, Sweden
#
# This is free software: you can redistribute it and/or modify
# it under the terms of the GNU Lesser General Public License as published by
# the Free Software Foundation, either version 3 of the License, or
# (at your option) any later version.

# This template is maintained by Johan Hoffman
# Please report problems to jhoffman@kth.se
# Out:
# 'KTH Royal Institute of Technology, Stockholm, Sweden.'

# %% [markdown]
# # **Set up environment**

# %%
# Load neccessary modules.
from google.colab import files

import numpy as np
import time

# Install FEniCS (this may take a long time)
try:
    import dolfin
except ImportError:
    # !wget "https://fem-on-colab.github.io/releases/fenics-install.sh" -O "/tmp/fenics-install.sh" && bash "/tmp/fenics-install.sh"
    import dolfin
    
from dolfin import *; from mshr import *

import dolfin.common.plotting as fenicsplot

from matplotlib import pyplot as plt

# %% [markdown]
# # **Introduction**

# %% [markdown]
# The Elasticity equations take the form
#
# $-\nabla \cdot \sigma = f$
#
# together with suitable boundary conditions.
#
# To derive the weak form of the equations, multiply the equation by $v\in V$, and then integrate over the domain $\Omega$ and use Green's formula
# $
# (-\nabla \cdot \sigma ,v) = (\nabla \sigma , \nabla v)
# - <\sigma \cdot n, v>_{\Gamma}
# $
#
# To model
#
# We seek a finite element approximation $u\in V$ such that
#
# $(\nabla \sigma,\nabla v) - <\sigma \cdot n, v>_{\partial \Omega} = (f,v)$
#
# for all test functions $v \in V$.
#
# The **aim** of this lab assignment is to:
# 1. Observe how the elastic material is deformed as a response to how the cylinders are moved inside the domain. How does the response change when Young's modulus or Poisson's ratio is changed?

# %% [markdown]
# # **Method**

# %% [markdown]
# **Define domain and mesh**

# %%
# Define rectangular domain 
L = 4.0
H = 2.0

# Define subdomains (for boundary conditions)
class Left(SubDomain):
    def inside(self, x, on_boundary):
        return near(x[0], 0.0) 

class Right(SubDomain):
    def inside(self, x, on_boundary):
        return near(x[0], L)

class Lower(SubDomain):
    def inside(self, x, on_boundary):
        return near(x[1], 0.0)

class Upper(SubDomain):
    def inside(self, x, on_boundary):
        return near(x[1], H)
      
left = Left()
right = Right()
lower = Lower()
upper = Upper()

# normalized circle locations
c1x = 0.375
c1y = 0.25
c2x = 0.125
c2y = 0.5
c3x = 0.5
c3y = 0.75
radius = 0.2

# Generate mesh (examples with and without a hole in the mesh) 
resolution = 32
mesh = generate_mesh(Rectangle(Point(0.0,0.0), Point(L,H)) - Circle(Point(c1x*L, c1y*H), radius) - Circle(Point(c2x*L, c2y*H), radius) - Circle(Point(c3x*L, c3y*H), radius), resolution)

# Local mesh refinement (specified by a cell marker)
no_levels = 0
for i in range(0,no_levels):
  cell_marker = MeshFunction("bool", mesh, mesh.topology().dim())
  for cell in cells(mesh):
    cell_marker[cell] = False
    p = cell.midpoint()
    if p.distance(Point(1.5, 0.5)) < 1.0:
        cell_marker[cell] = True
  mesh = refine(mesh, cell_marker)

# Define mesh functions (for boundary conditions)
boundaries = MeshFunction("size_t", mesh, mesh.topology().dim()-1)
boundaries.set_all(0)
left.mark(boundaries, 1)
right.mark(boundaries, 2)
lower.mark(boundaries, 3)
upper.mark(boundaries, 4)

plt.figure(figsize=(12, 6))
plot(mesh, title="Mesh with circles at (" + str(c1x*L) + ", " + str(c1y*H) + "), (" + str(c2x*L) + ", " + str(c2y*H) + "), (" + str(c3x*L) + ", " + str(c3y*H) + ")")
plt.show()

# %% [markdown]
# **Define finite element approximation spaces**

# %%
# Generate finite element space
VE = VectorElement("CG", mesh.ufl_cell(), 1)

V = FunctionSpace(mesh, VE)

# Define trial and test functions
u = TrialFunction(V)
v = TestFunction(V) 

d = Function(V)

# %% [markdown]
# **Define boundary conditions**

# %%
# Define boundary conditions 
class DirichletBoundaryLower(SubDomain):
    def inside(self, x, on_boundary):
        return on_boundary and near(x[1], 0.0)

class DirichletBoundaryUpper(SubDomain):
    def inside(self, x, on_boundary):
        return on_boundary and near(x[1], H)

class DirichletBoundaryLeft(SubDomain):
    def inside(self, x, on_boundary):
        return on_boundary and near(x[0], 0.0) 

class DirichletBoundaryRight(SubDomain):
    def inside(self, x, on_boundary):
        return on_boundary and near(x[0], L)

class DirichletBoundaryObjects(SubDomain):
    def inside(self, x, on_boundary):
        return on_boundary and (not near(x[0], 0.0)) and (not near(x[0], L)) and (not near(x[1], 0.0)) and (not near(x[1], H))

dbc_lower = DirichletBoundaryLower()
dbc_upper = DirichletBoundaryUpper()
dbc_left = DirichletBoundaryLeft()
dbc_right = DirichletBoundaryRight()
dbc_objects = DirichletBoundaryObjects()

# prescribed deformation
deff_x = 0.5
deff_y = 0.2

bcu_left0 = DirichletBC(V.sub(0), 0.0, dbc_left)
bcu_left1 = DirichletBC(V.sub(1), 0.0, dbc_left)
bcu_right0 = DirichletBC(V.sub(0), 0.0, dbc_right)
bcu_right1 = DirichletBC(V.sub(1), 0.0, dbc_right)
bcu_upper0 = DirichletBC(V.sub(0), 0.0, dbc_upper)
bcu_upper1 = DirichletBC(V.sub(1), 0.0, dbc_upper)
bcu_lower0 = DirichletBC(V.sub(0), 0.0, dbc_lower)
bcu_lower1 = DirichletBC(V.sub(1), 0.0, dbc_lower)
bcu_obj0 = DirichletBC(V.sub(0), deff_x, dbc_objects)
bcu_obj1 = DirichletBC(V.sub(1), deff_y, dbc_objects)

#bcu = [bcu_in0, bcu_in1, bcu_upp0, bcu_upp1, bcu_low0, bcu_low1, bcu_obj0, bcu_obj1]
bcu = [bcu_left0, bcu_left1, bcu_right0, bcu_right1, bcu_upper0, bcu_upper1, bcu_lower0, bcu_lower1, bcu_obj0, bcu_obj1]

# %% [markdown]
# # **Results**
#
# First the deformation response to a prescribed and equal object displacement was investigated. The relaxed mesh without displacement is shown below:
#
# INSERT
#
# When the objects are displaced 0.5 l.e. to the right, the mesh deforms as shown below:
#
# INSERT
#
# INSERT
#
# When the objects are displaced 0.2 l.e. upwards, the mesh deforms as shown below:
#
# INSERT
#
# INSERT
#
# When the objects are displaced 0.2 l.e. upwards, and 0.5 l.e. to the right, the mesh deforms as below:
#
# INSERT
#
# INSERT
#
# Looking at the last case in particular, Young's modulus was doubled to 2e10. Young's modulus is a measure of how much stress is required to deform the material a particular amount, so with a prescribed displacement the effect is to increase all stresses. The result is shown below:
#
# INSERT
#
# INSERT
#
# Poisson's ratio was decreased to 0.1. Poisson's ratio is a measure on how much transverse deformation the material experience in response to the deformation in the load direction. The result is shown below:
#
# INSERT
#
# INSERT
#
# Finally Poisson's ratio was increased to 0.45. The result is shown below:
#
# INSERT
#
# INSERT

# %% [markdown]
# **Define and solve variational problem**

# %%
f = Expression(("0.0","0.0"), element = V.ufl_element())

dim = u.geometric_dimension()
E = 1.0e10  # young's modulus
nu = 0.45    # poisson's ratio
mu = E*0.5/(1+nu)
lambda_ = nu*E/((1.0+nu)*(1.0-2.0*nu))

def epsilon(u):
    return 0.5*(grad(u) + grad(u).T)

def sigma(u):
    #return 2.0*mu*epsilon(u)
    return lambda_*div(u)*Identity(dim) + 2.0*mu*epsilon(u)

# Define variational problem on residual form: r(u,v) = 0
residual = ( inner(sigma(u), epsilon(v))*dx - inner(f, v)*dx )

au = lhs(residual)
Lu = rhs(residual)

A = assemble(au)
b = assemble(Lu)

[bc.apply(A, b) for bc in bcu]
[bc.apply(d.vector()) for bc in bcu]

solve(A, d.vector(), b, "bicgstab", "default")
# Out:
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# 22

# %% [markdown]
# **Visualize solution and export files**

# %%
u1 = project(d, V)

# Plot solution
plt.figure(figsize=(12, 6))
plot(u1, title="Displacement with object deformation (" + str(deff_x) + ", " + str(deff_y) + ")")

plt.show()

# %% [markdown]
# **Update mesh**

# %%
ALE.move(mesh, d)
plt.figure(figsize=(12, 6))
plot(mesh, title="Deformed mesh with object deformation (" + str(deff_x) + ", " + str(deff_y) + ")")
plt.show()

# %% [markdown]
# # **Discussion**

# %% [markdown]
# A Elasticity equation was solved with a finite element method.
#
# The results are as would be expected from solid mechanics. The material between the objects generally follows the displacement of the objects. Changing Young's modulus doesn't impact the deformation solution since it will simply scale the stresses to achieve the same displacement. Changing Poisson's ration changes the solution; in particular increasing Poisson's ratio results in larger deformations in the directions transverse to the displacement vector since material gets pulled in more strongly behind the displaced objects, and pushed out more strongly in front of them.
